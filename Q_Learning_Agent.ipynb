# %% [markdown]
# <a href="https://colab.research.google.com/github/EnterTheBeginning/Trading_Agents/blob/master/Q_Learning_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/2.Intelligent Systems/data/google_year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-6-9934fc4f9176>:26: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# epoch: 10, total rewards: 372.235166.3, cost: 1.783787, total money: 10372.235166
# epoch: 20, total rewards: 358.745178.3, cost: 0.733625, total money: 10358.745178
# epoch: 30, total rewards: 305.575256.3, cost: 0.480665, total money: 10305.575256
# epoch: 40, total rewards: 394.185240.3, cost: 0.357627, total money: 10394.185240
# epoch: 50, total rewards: 402.425231.3, cost: 0.275874, total money: 10402.425231
# epoch: 60, total rewards: 317.145202.3, cost: 0.614819, total money: 10317.145202
# epoch: 70, total rewards: 293.995177.3, cost: 0.180018, total money: 10293.995177
# epoch: 80, total rewards: 414.735289.3, cost: 0.148903, total money: 10414.735289
# epoch: 90, total rewards: 415.145262.3, cost: 0.144667, total money: 10415.145262
# epoch: 100, total rewards: 305.255186.3, cost: 0.107814, total money: 10305.255186
# epoch: 110, total rewards: 415.715208.3, cost: 0.113726, total money: 10415.715208
# epoch: 120, total rewards: 407.115232.3, cost: 0.099431, total money: 10407.115232
# epoch: 130, total rewards: 217.725219.3, cost: 0.070535, total money: 10217.725219
# epoch: 140, total rewards: 305.655211.3, cost: 0.063806, total money: 10305.655211
# epoch: 150, total rewards: 408.585203.3, cost: 0.076178, total money: 10408.585203
# epoch: 160, total rewards: 298.485228.3, cost: 0.051335, total money: 10298.485228
# epoch: 170, total rewards: 371.625184.3, cost: 0.067347, total money: 10371.625184
# epoch: 180, total rewards: 284.165160.3, cost: 0.061125, total money: 10284.165160
# epoch: 190, total rewards: 358.365233.3, cost: 0.040767, total money: 10358.365233
# epoch: 200, total rewards: 368.845274.3, cost: 0.038016, total money: 10368.845274

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 7: buy 1 unit at price 754.020020, total balance 9245.979980
# day 8: buy 1 unit at price 736.080017, total balance 8509.899963
# day 10, sell 1 unit at price 764.479980, investment 1.387226 %, total balance 9274.379943,
# day 13, sell 1 unit at price 769.200012, investment 4.499510 %, total balance 10043.579955,
# day 31: buy 1 unit at price 790.799988, total balance 9252.779967
# day 32, sell 1 unit at price 794.200012, investment 0.429947 %, total balance 10046.979979,
# day 33: buy 1 unit at price 796.419983, total balance 9250.559996
# day 34, sell 1 unit at price 794.559998, investment -0.233543 %, total balance 10045.119994,
# day 35: buy 1 unit at price 791.260010, total balance 9253.859984
# day 36, sell 1 unit at price 789.909973, investment -0.170619 %, total balance 10043.769957,
# day 38: buy 1 unit at price 785.049988, total balance 9258.719969
# day 42: buy 1 unit at price 786.900024, total balance 8471.819945
# day 43, sell 1 unit at price 794.020020, investment 1.142606 %, total balance 9265.839965,
# day 44, sell 1 unit at price 806.150024, investment 2.446308 %, total balance 10071.989989,
# day 46: buy 1 unit at price 804.789978, total balance 9267.200011
# day 47: buy 1 unit at price 807.909973, total balance 8459.290038
# day 53, sell 1 unit at price 805.020020, investment 0.028584 %, total balance 9264.310058,
# day 54: buy 1 unit at price 819.309998, total balance 8445.000060
# day 55: buy 1 unit at price 823.869995, total balance 7621.130065
# day 57: buy 1 unit at price 832.150024, total balance 6788.980041
# day 61: buy 1 unit at price 795.695007, total balance 5993.285034
# day 62, sell 1 unit at price 798.530029, investment -1.161014 %, total balance 6791.815063,
# day 66, sell 1 unit at price 808.380005, investment -1.334049 %, total balance 7600.195068,
# day 67, sell 1 unit at price 809.559998, investment -1.736924 %, total balance 8409.755066,
# day 68, sell 1 unit at price 813.669983, investment -2.220758 %, total balance 9223.425049,
# day 69, sell 1 unit at price 819.239990, investment 2.959046 %, total balance 10042.665039,
# day 74: buy 1 unit at price 831.659973, total balance 9211.005066
# day 75, sell 1 unit at price 830.760010, investment -0.108213 %, total balance 10041.765076,
# day 77: buy 1 unit at price 828.640015, total balance 9213.125061
# day 78, sell 1 unit at price 829.280029, investment 0.077237 %, total balance 10042.405090,
# day 82: buy 1 unit at price 829.080017, total balance 9213.325073
# day 83, sell 1 unit at price 827.780029, investment -0.156799 %, total balance 10041.105102,
# day 84: buy 1 unit at price 831.909973, total balance 9209.195129
# day 85: buy 1 unit at price 835.369995, total balance 8373.825134
# day 87, sell 1 unit at price 843.250000, investment 1.363132 %, total balance 9217.075134,
# day 89, sell 1 unit at price 845.619995, investment 1.227001 %, total balance 10062.695129,
# day 93: buy 1 unit at price 848.400024, total balance 9214.295105
# day 96: buy 1 unit at price 817.580017, total balance 8396.715088
# day 97: buy 1 unit at price 814.429993, total balance 7582.285095
# day 98, sell 1 unit at price 819.510010, investment -3.405235 %, total balance 8401.795105,
# day 99, sell 1 unit at price 820.919983, investment 0.408519 %, total balance 9222.715088,
# day 100, sell 1 unit at price 831.409973, investment 2.084891 %, total balance 10054.125061,
# day 104: buy 1 unit at price 834.570007, total balance 9219.555054
# day 105: buy 1 unit at price 831.409973, total balance 8388.145081
# day 107, sell 1 unit at price 824.669983, investment -1.186242 %, total balance 9212.815064,
# day 108: buy 1 unit at price 824.729980, total balance 8388.085084
# day 110, sell 1 unit at price 824.320007, investment -0.852764 %, total balance 9212.405091,
# day 112, sell 1 unit at price 837.169983, investment 1.508373 %, total balance 10049.575074,
# day 120: buy 1 unit at price 874.250000, total balance 9175.325074
# day 121: buy 1 unit at price 905.960022, total balance 8269.365052
# day 122, sell 1 unit at price 912.570007, investment 4.383186 %, total balance 9181.935059,
# day 124: buy 1 unit at price 927.039978, total balance 8254.895081
# day 127, sell 1 unit at price 934.299988, investment 3.128170 %, total balance 9189.195069,
# day 128: buy 1 unit at price 932.169983, total balance 8257.025086
# day 130: buy 1 unit at price 930.599976, total balance 7326.425110
# day 131: buy 1 unit at price 932.219971, total balance 6394.205139
# day 132, sell 1 unit at price 937.080017, investment 1.083021 %, total balance 7331.285156,
# day 133: buy 1 unit at price 943.000000, total balance 6388.285156
# day 134: buy 1 unit at price 919.619995, total balance 5468.665161
# day 135: buy 1 unit at price 930.239990, total balance 4538.425171
# day 136, sell 1 unit at price 934.010010, investment 0.197392 %, total balance 5472.435181,
# day 137, sell 1 unit at price 941.859985, investment 1.209973 %, total balance 6414.295166,
# day 138, sell 1 unit at price 948.820007, investment 1.780699 %, total balance 7363.115173,
# day 141: buy 1 unit at price 971.469971, total balance 6391.645202
# day 142, sell 1 unit at price 975.880005, investment 3.486745 %, total balance 7367.525207,
# day 144, sell 1 unit at price 966.950012, investment 5.146693 %, total balance 8334.475219,
# day 145, sell 1 unit at price 975.599976, investment 4.876160 %, total balance 9310.075195,
# day 147, sell 1 unit at price 976.570007, investment 0.524981 %, total balance 10286.645202,
# day 149: buy 1 unit at price 983.409973, total balance 9303.235229
# day 150, sell 1 unit at price 949.830017, investment -3.414645 %, total balance 10253.065246,
# day 152: buy 1 unit at price 953.400024, total balance 9299.665222
# day 153, sell 1 unit at price 950.760010, investment -0.276905 %, total balance 10250.425232,
# day 155: buy 1 unit at price 939.780029, total balance 9310.645203
# day 156, sell 1 unit at price 957.369995, investment 1.871711 %, total balance 10268.015198,
# day 173: buy 1 unit at price 947.159973, total balance 9320.855225
# day 174: buy 1 unit at price 955.989990, total balance 8364.865235
# day 175, sell 1 unit at price 953.419983, investment 0.660924 %, total balance 9318.285218,
# day 176, sell 1 unit at price 965.400024, investment 0.984323 %, total balance 10283.685242,
# day 177: buy 1 unit at price 970.890015, total balance 9312.795227
# day 180: buy 1 unit at price 980.340027, total balance 8332.455200
# day 181: buy 1 unit at price 950.700012, total balance 7381.755188
# day 182, sell 1 unit at price 947.799988, investment -2.378233 %, total balance 8329.555176,
# day 183, sell 1 unit at price 934.090027, investment -4.717751 %, total balance 9263.645203,
# day 184: buy 1 unit at price 941.530029, total balance 8322.115174
# day 186: buy 1 unit at price 930.830017, total balance 7391.285157
# day 187, sell 1 unit at price 930.390015, investment -2.136320 %, total balance 8321.675172,
# day 188: buy 1 unit at price 923.650024, total balance 7398.025148
# day 189: buy 1 unit at price 927.960022, total balance 6470.065126
# day 190: buy 1 unit at price 929.359985, total balance 5540.705141
# day 193: buy 1 unit at price 907.239990, total balance 4633.465151
# day 195, sell 1 unit at price 922.669983, investment -2.003127 %, total balance 5556.135134,
# day 197: buy 1 unit at price 926.960022, total balance 4629.175112
# day 199, sell 1 unit at price 910.669983, investment -2.165813 %, total balance 5539.845095,
# day 200: buy 1 unit at price 906.659973, total balance 4633.185122
# day 201, sell 1 unit at price 924.690002, investment 0.112594 %, total balance 5557.875124,
# day 202, sell 1 unit at price 927.000000, investment -0.103455 %, total balance 6484.875124,
# day 203, sell 1 unit at price 921.280029, investment -0.869411 %, total balance 7406.155153,
# day 205, sell 1 unit at price 913.809998, investment 0.724175 %, total balance 8319.965151,
# day 206: buy 1 unit at price 921.289978, total balance 7398.675173
# day 207, sell 1 unit at price 929.570007, investment 0.281564 %, total balance 8328.245180,
# day 208: buy 1 unit at price 939.330017, total balance 7388.915163
# day 209, sell 1 unit at price 937.340027, investment 3.383854 %, total balance 8326.255190,
# day 212: buy 1 unit at price 935.950012, total balance 7390.305178
# day 213, sell 1 unit at price 926.500000, investment 0.565514 %, total balance 8316.805178,
# day 215, sell 1 unit at price 932.070007, investment -0.772892 %, total balance 9248.875185,
# day 216, sell 1 unit at price 935.090027, investment -0.091884 %, total balance 10183.965212,
# day 225: buy 1 unit at price 924.859985, total balance 9259.105227
# day 226, sell 1 unit at price 944.489990, investment 2.122484 %, total balance 10203.595217,
# day 229: buy 1 unit at price 953.270020, total balance 9250.325197
# day 231: buy 1 unit at price 951.679993, total balance 8298.645204
# day 233, sell 1 unit at price 978.890015, investment 2.687591 %, total balance 9277.535219,
# day 237, sell 1 unit at price 987.830017, investment 3.798548 %, total balance 10265.365236,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
