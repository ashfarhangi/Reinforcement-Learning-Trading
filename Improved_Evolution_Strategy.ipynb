# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkanfarhangi/Reinforcement-Learning-Trading/blob/master/Improved_Evolution_Strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/UCF_Intelligent Systems/data/Google1819.csv')
df.head()
# Out:
#          Date         Open         High  ...        Close    Adj Close   Volume
# 0  2018-01-02  1048.339966  1066.939941  ...  1065.000000  1065.000000  1237600
# 1  2018-01-03  1064.310059  1086.290039  ...  1082.479980  1082.479980  1430200
# 2  2018-01-04  1088.000000  1093.569946  ...  1086.400024  1086.400024  1004600
# 3  2018-01-05  1094.000000  1104.250000  ...  1102.229980  1102.229980  1279100
# 4  2018-01-08  1102.229980  1111.270020  ...  1106.939941  1106.939941  1047600
#
# [5 rows x 7 columns]

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.9.0
# pandas==0.24.2
# numpy==1.16.3
# matplotlib==3.0.3
# google==2.0.2

# %% [markdown]
# # Deep Evolution Strategy:

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]
#Prediction used to update the weights
    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision
#Weights are being updated after each iteration
    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        portfolio = []
        investmentPortfolio =[]
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                portfolio.append(initial_money)
                states_buy.append(t)
                
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                portfolio.append(initial_money)
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                    investmentPortfolio.append(invest)
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest, portfolio ,investmentPortfolio

# %% [markdown]
# #Training

# %%
#Tweaking goes here
#w 30 ,i 12k,l 300 > S = 36 48
#w 30 ,i 12k,l 300 > S = 29 38 2.5k=54

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 12000

model = Model(input_size = window_size, layer_size = 300, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 20000, checkpoint = 100)
# Out:
# iter 100. reward: 29.040501
# iter 200. reward: 38.376419
# iter 300. reward: 44.428920
# iter 400. reward: 48.836587
# iter 500. reward: 48.593253
# iter 600. reward: 50.398918
# iter 700. reward: 50.820669
# iter 800. reward: 52.081168
# iter 900. reward: 52.260417
# iter 1000. reward: 52.237917
# iter 1100. reward: 51.731169
# iter 1200. reward: 51.902337
# iter 1300. reward: 53.944837
# iter 1400. reward: 54.263586
# iter 1500. reward: 53.712837
# iter 1600. reward: 54.275418
# iter 1700. reward: 53.618250
# iter 1800. reward: 51.725669
# iter 1900. reward: 54.174421
# iter 2000. reward: 54.240170
# iter 2100. reward: 54.355752
# iter 2200. reward: 51.225753
# iter 2300. reward: 54.781086
# iter 2400. reward: 53.564336
# iter 2500. reward: 54.358752
# iter 2600. reward: 54.368502
# iter 2700. reward: 51.001584
# iter 2800. reward: 54.822335
# iter 2900. reward: 54.786501
# iter 3000. reward: 54.286919
# iter 3100. reward: 55.218751
# iter 3200. reward: 54.722835
# iter 3300. reward: 55.442585
# iter 3400. reward: 55.025587
# iter 3500. reward: 53.486335
# iter 3600. reward: 54.964585
# iter 3700. reward: 56.081253
# iter 3800. reward: 56.455670
# iter 3900. reward: 56.328336
# iter 4000. reward: 56.566170
# iter 4100. reward: 56.112168
# iter 4200. reward: 55.411252
# iter 4300. reward: 56.409334
# iter 4400. reward: 56.553918
# iter 4500. reward: 56.700085
# iter 4600. reward: 56.687835
# iter 4700. reward: 56.054501
# iter 4800. reward: 56.231835
# iter 4900. reward: 56.437419
# iter 5000. reward: 57.146920
# iter 5100. reward: 57.076003
# iter 5200. reward: 57.122169
# iter 5300. reward: 57.133420
# iter 5400. reward: 46.907502
# iter 5500. reward: 56.672502
# iter 5600. reward: 57.660668
# iter 5700. reward: 58.055503
# iter 5800. reward: 57.442335
# iter 5900. reward: 58.065502
# iter 6000. reward: 56.910003
# iter 6100. reward: 56.050086
# iter 6200. reward: 56.770419
# iter 6300. reward: 56.887919
# iter 6400. reward: 57.267585
# iter 6500. reward: 57.089583
# iter 6600. reward: 57.051335
# iter 6700. reward: 57.372668
# iter 6800. reward: 57.223085
# iter 6900. reward: 56.768000
# iter 7000. reward: 56.794418
# iter 7100. reward: 57.216333
# iter 7200. reward: 57.703585
# iter 7300. reward: 57.459584
# iter 7400. reward: 57.862502
# iter 7500. reward: 58.012502
# iter 7600. reward: 57.925835
# iter 7700. reward: 58.066086
# iter 7800. reward: 57.855419
# iter 7900. reward: 57.655918
# iter 8000. reward: 57.634835
# iter 8100. reward: 57.700085
# iter 8200. reward: 57.178752
# iter 8300. reward: 57.489586
# iter 8400. reward: 57.904501
# iter 8500. reward: 58.130586
# iter 8600. reward: 58.576835
# iter 8700. reward: 58.594419
# iter 8800. reward: 58.772002
# iter 8900. reward: 58.777336
# iter 9000. reward: 58.825336
# iter 9100. reward: 58.686752
# iter 9200. reward: 58.872504
# iter 9300. reward: 58.889420
# iter 9400. reward: 58.730918
# iter 9500. reward: 58.976002
# iter 9600. reward: 58.891669
# iter 9700. reward: 58.749002
# iter 9800. reward: 58.895336
# iter 9900. reward: 59.008668
# iter 10000. reward: 58.171252
# iter 10100. reward: 58.925170
# iter 10200. reward: 58.615919
# iter 10300. reward: 58.867002
# iter 10400. reward: 59.051585
# iter 10500. reward: 56.463002
# iter 10600. reward: 56.644170
# iter 10700. reward: 56.966503
# iter 10800. reward: 56.948587
# iter 10900. reward: 57.269836
# iter 11000. reward: 57.601253
# iter 11100. reward: 57.699336
# iter 11200. reward: 57.745668
# iter 11300. reward: 57.737419
# iter 11400. reward: 57.831669
# iter 11500. reward: 57.687585
# iter 11600. reward: 57.897586
# iter 11700. reward: 57.977252
# iter 11800. reward: 57.890419
# iter 11900. reward: 58.052002
# iter 12000. reward: 57.850752
# iter 12100. reward: 58.185586
# iter 12200. reward: 57.849418
# iter 12300. reward: 58.016001
# iter 12400. reward: 57.772834
# iter 12500. reward: 57.938500
# iter 12600. reward: 58.169585
# iter 12700. reward: 58.400918
# iter 12800. reward: 58.409502
# iter 12900. reward: 58.389418
# iter 13000. reward: 58.332001
# iter 13100. reward: 58.210585
# iter 13200. reward: 58.579335
# iter 13300. reward: 58.535168
# iter 13400. reward: 58.487168
# iter 13500. reward: 59.360502
# iter 13600. reward: 59.441252
# iter 13700. reward: 59.214252
# iter 13800. reward: 59.415751
# iter 13900. reward: 59.297585
# iter 14000. reward: 59.523667
# iter 14100. reward: 59.507001
# iter 14200. reward: 59.523667
# iter 14300. reward: 59.447667
# iter 14400. reward: 59.333834
# iter 14500. reward: 59.329751
# iter 14600. reward: 59.397000
# iter 14700. reward: 59.887250
# iter 14800. reward: 59.868583
# iter 14900. reward: 59.281167
# iter 15000. reward: 59.640084
# iter 15100. reward: 59.228083
# iter 15200. reward: 59.430584
# iter 15300. reward: 59.470167
# iter 15400. reward: 59.349417
# iter 15500. reward: 59.360000
# iter 15600. reward: 59.318501
# iter 15700. reward: 59.373750
# iter 15800. reward: 59.373750
# iter 15900. reward: 59.349417
# iter 16000. reward: 59.448499
# iter 16100. reward: 59.448499
# iter 16200. reward: 59.431001
# iter 16300. reward: 59.530083
# iter 16400. reward: 58.314332
# iter 16500. reward: 59.530083
# iter 16600. reward: 59.621084
# iter 16700. reward: 59.702667
# iter 16800. reward: 59.702667
# iter 16900. reward: 59.628417
# iter 17000. reward: 59.483001
# iter 17100. reward: 59.440001
# iter 17200. reward: 60.433834
# iter 17300. reward: 60.571917
# iter 17400. reward: 60.413250
# iter 17500. reward: 60.521167
# iter 17600. reward: 60.280584
# iter 17700. reward: 60.066583
# iter 17800. reward: 60.364000
# iter 17900. reward: 60.409917
# iter 18000. reward: 60.335667
# iter 18100. reward: 60.481417
# iter 18200. reward: 60.482834
# iter 18300. reward: 60.501500
# iter 18400. reward: 60.337084
# iter 18500. reward: 60.355750
# iter 18600. reward: 60.348417
# iter 18700. reward: 60.355750
# iter 18800. reward: 60.182750
# iter 18900. reward: 60.392584
# iter 19000. reward: 60.348417
# iter 19100. reward: 60.344584
# iter 19200. reward: 60.315084
# iter 19300. reward: 60.346501
# iter 19400. reward: 60.392584
# iter 19500. reward: 60.335750
# iter 19600. reward: 60.284918
# iter 19700. reward: 60.287750
# iter 19800. reward: 60.123584
# iter 19900. reward: 60.180418
# iter 20000. reward: 60.180418
# time taken to train: 2008.772938966751 seconds

# %%
i

# %%
states_buy, states_sell, total_gains, invest,portfolio,investmentPortfolio = agent.buy()
# Out:
# day 0: buy 1 unit at price 1065.000000, total balance 10935.000000
# day 1, sell 1 unit at price 1082.479980, investment 1.641313 %, total balance 12017.479980,
# day 19: buy 1 unit at price 1163.689941, total balance 10853.790039
# day 20, sell 1 unit at price 1169.939941, investment 0.537085 %, total balance 12023.729980,
# day 22: buy 1 unit at price 1111.900024, total balance 10911.829956
# day 23: buy 1 unit at price 1055.800049, total balance 9856.029907
# day 24: buy 1 unit at price 1080.599976, total balance 8775.429931
# day 25: buy 1 unit at price 1048.579956, total balance 7726.849975
# day 26: buy 1 unit at price 1001.520020, total balance 6725.329955
# day 27: buy 1 unit at price 1037.780029, total balance 5687.549926
# day 29: buy 1 unit at price 1052.099976, total balance 4635.449950
# day 30: buy 1 unit at price 1069.699951, total balance 3565.749999
# day 32, sell 1 unit at price 1094.800049, investment -1.537906 %, total balance 4660.550048,
# day 33: buy 1 unit at price 1102.459961, total balance 3558.090087
# day 36, sell 1 unit at price 1126.790039, investment 6.723810 %, total balance 4684.880126,
# day 38, sell 1 unit at price 1118.290039, investment 3.487883 %, total balance 5803.170165,
# day 39, sell 1 unit at price 1104.729980, investment 5.354863 %, total balance 6907.900145,
# day 42, sell 1 unit at price 1090.930054, investment 8.927434 %, total balance 7998.830199,
# day 45, sell 1 unit at price 1126.000000, investment 8.500835 %, total balance 9124.830199,
# day 46, sell 1 unit at price 1160.040039, investment 10.259487 %, total balance 10284.870238,
# day 47, sell 1 unit at price 1164.500000, investment 8.862303 %, total balance 11449.370238,
# day 48, sell 1 unit at price 1138.170044, investment 3.239127 %, total balance 12587.540282,
# day 50: buy 1 unit at price 1149.579956, total balance 11437.960326
# day 51, sell 1 unit at price 1135.729980, investment -1.204786 %, total balance 12573.690306,
# day 52: buy 1 unit at price 1099.819946, total balance 11473.870360
# day 54, sell 1 unit at price 1090.880005, investment -0.812855 %, total balance 12564.750365,
# day 55: buy 1 unit at price 1049.079956, total balance 11515.670409
# day 56: buy 1 unit at price 1021.570007, total balance 10494.100402
# day 58: buy 1 unit at price 1005.099976, total balance 9489.000426
# day 59: buy 1 unit at price 1004.559998, total balance 8484.440428
# day 60: buy 1 unit at price 1031.790039, total balance 7452.650389
# day 62: buy 1 unit at price 1013.409973, total balance 6439.240416
# day 63: buy 1 unit at price 1025.140015, total balance 5414.100401
# day 65: buy 1 unit at price 1007.039978, total balance 4407.060423
# day 66: buy 1 unit at price 1015.450012, total balance 3391.610411
# day 67: buy 1 unit at price 1031.640015, total balance 2359.970396
# day 68: buy 1 unit at price 1019.969971, total balance 1340.000425
# day 69: buy 1 unit at price 1032.510010, total balance 307.490415
# day 71, sell 1 unit at price 1037.979980, investment -1.058068 %, total balance 1345.470395,
# day 72, sell 1 unit at price 1074.160034, investment 5.147961 %, total balance 2419.630429,
# day 74, sell 1 unit at price 1087.699951, investment 8.218085 %, total balance 3507.330380,
# day 75, sell 1 unit at price 1072.959961, investment 6.808948 %, total balance 4580.290341,
# day 77, sell 1 unit at price 1019.979980, investment -1.144618 %, total balance 5600.270321,
# day 78: buy 1 unit at price 1021.179993, total balance 4579.090328
# day 80: buy 1 unit at price 1030.050049, total balance 3549.040279
# day 81: buy 1 unit at price 1017.330017, total balance 2531.710262
# day 83: buy 1 unit at price 1024.380005, total balance 1507.330257
# day 84: buy 1 unit at price 1023.719971, total balance 483.610286
# day 90, sell 1 unit at price 1098.260010, investment 8.372726 %, total balance 1581.870296,
# day 91, sell 1 unit at price 1100.199951, investment 7.321920 %, total balance 2682.070247,
# day 93, sell 1 unit at price 1081.770020, investment 7.420762 %, total balance 3763.840267,
# day 94, sell 1 unit at price 1078.589966, investment 6.217928 %, total balance 4842.430233,
# day 95: buy 1 unit at price 1066.359985, total balance 3776.070248
# day 97: buy 1 unit at price 1069.729980, total balance 2706.340268
# day 99: buy 1 unit at price 1079.239990, total balance 1627.100278
# day 100, sell 1 unit at price 1075.660034, investment 4.266994 %, total balance 2702.760312,
# day 101: buy 1 unit at price 1060.319946, total balance 1642.440366
# day 102: buy 1 unit at price 1067.800049, total balance 574.640317
# day 105, sell 1 unit at price 1139.290039, investment 11.698390 %, total balance 1713.930356,
# day 106, sell 1 unit at price 1139.660034, investment 10.377626 %, total balance 2853.590390,
# day 107: buy 1 unit at price 1136.880005, total balance 1716.710385
# day 108, sell 1 unit at price 1123.859985, investment 10.055034 %, total balance 2840.570370,
# day 109: buy 1 unit at price 1120.869995, total balance 1719.700375
# day 110: buy 1 unit at price 1129.989990, total balance 589.710385
# day 111, sell 1 unit at price 1139.319946, investment 10.608212 %, total balance 1729.030331,
# day 112, sell 1 unit at price 1134.790039, investment 11.545911 %, total balance 2863.820370,
# day 113, sell 1 unit at price 1152.119995, investment 12.469981 %, total balance 4015.940365,
# day 114, sell 1 unit at price 1152.260010, investment 12.556172 %, total balance 5168.200375,
# day 115, sell 1 unit at price 1173.459961, investment 10.043510 %, total balance 6341.660336,
# day 116, sell 1 unit at price 1168.060059, investment 9.192047 %, total balance 7509.720395,
# day 117, sell 1 unit at price 1169.839966, investment 8.394794 %, total balance 8679.560361,
# day 119, sell 1 unit at price 1155.479980, investment 8.974653 %, total balance 9835.040341,
# day 120: buy 1 unit at price 1124.810059, total balance 8710.230282
# day 121: buy 1 unit at price 1118.459961, total balance 7591.770321
# day 122: buy 1 unit at price 1103.979980, total balance 6487.790341
# day 123: buy 1 unit at price 1114.219971, total balance 5373.570370
# day 124: buy 1 unit at price 1115.650024, total balance 4257.920346
# day 125: buy 1 unit at price 1127.459961, total balance 3130.460385
# day 126: buy 1 unit at price 1102.890015, total balance 2027.570370
# day 127: buy 1 unit at price 1124.270020, total balance 903.300350
# day 129, sell 1 unit at price 1154.050049, investment 8.077355 %, total balance 2057.350399,
# day 130: buy 1 unit at price 1152.839966, total balance 904.510433
# day 132, sell 1 unit at price 1183.479980, investment 4.098935 %, total balance 2087.990413,
# day 133, sell 1 unit at price 1188.819946, investment 6.062251 %, total balance 3276.810359,
# day 134: buy 1 unit at price 1183.859985, total balance 2092.950374
# day 136, sell 1 unit at price 1195.880005, investment 5.831026 %, total balance 3288.830379,
# day 137, sell 1 unit at price 1186.959961, investment 5.525369 %, total balance 4475.790340,
# day 138: buy 1 unit at price 1184.910034, total balance 3290.880306
# day 140, sell 1 unit at price 1248.079956, investment 11.589149 %, total balance 4538.960262,
# day 141, sell 1 unit at price 1263.699951, investment 14.467651 %, total balance 5802.660213,
# day 142, sell 1 unit at price 1268.329956, investment 13.831199 %, total balance 7070.990169,
# day 143, sell 1 unit at price 1238.500000, investment 11.011516 %, total balance 8309.490169,
# day 144, sell 1 unit at price 1219.739990, investment 8.184772 %, total balance 9529.230159,
# day 145, sell 1 unit at price 1217.260010, investment 10.370027 %, total balance 10746.490169,
# day 146: buy 1 unit at price 1220.010010, total balance 9526.480159
# day 147, sell 1 unit at price 1226.150024, investment 9.061880 %, total balance 10752.630183,
# day 148: buy 1 unit at price 1223.709961, total balance 9528.920222
# day 149, sell 1 unit at price 1224.770020, investment 6.239379 %, total balance 10753.690242,
# day 150, sell 1 unit at price 1242.219971, investment 4.929636 %, total balance 11995.910213,
# day 151, sell 1 unit at price 1245.609985, investment 5.122748 %, total balance 13241.520198,
# day 152, sell 1 unit at price 1249.099976, investment 2.384404 %, total balance 14490.620174,
# day 153: buy 1 unit at price 1237.609985, total balance 13253.010189
# day 154, sell 1 unit at price 1235.010010, investment 0.923425 %, total balance 14488.020199,
# day 155, sell 1 unit at price 1242.099976, investment 0.362795 %, total balance 15730.120175,
# day 157: buy 1 unit at price 1206.489990, total balance 14523.630185
# day 158: buy 1 unit at price 1200.959961, total balance 13322.670224
# day 159, sell 1 unit at price 1207.770020, investment 0.106095 %, total balance 14530.440244,
# day 160: buy 1 unit at price 1201.619995, total balance 13328.820249
# day 161: buy 1 unit at price 1207.329956, total balance 12121.490293
# day 162: buy 1 unit at price 1205.380005, total balance 10916.110288
# day 163: buy 1 unit at price 1220.650024, total balance 9695.460264
# day 164, sell 1 unit at price 1241.819946, investment 3.402277 %, total balance 10937.280210,
# day 165, sell 1 unit at price 1231.150024, investment 2.457518 %, total balance 12168.430234,
# day 166, sell 1 unit at price 1249.300049, investment 3.476274 %, total balance 13417.730283,
# day 167, sell 1 unit at price 1239.119995, investment 2.799116 %, total balance 14656.850278,
# day 168, sell 1 unit at price 1218.189941, investment -0.201539 %, total balance 15875.040219,
# day 171: buy 1 unit at price 1171.439941, total balance 14703.600278
# day 172: buy 1 unit at price 1164.829956, total balance 13538.770322
# day 173: buy 1 unit at price 1164.640015, total balance 12374.130307
# day 175: buy 1 unit at price 1162.819946, total balance 11211.310361
# day 176: buy 1 unit at price 1175.329956, total balance 10035.980405
# day 178, sell 1 unit at price 1156.050049, investment -1.313759 %, total balance 11192.030454,
# day 180: buy 1 unit at price 1171.089966, total balance 10020.940488
# day 181, sell 1 unit at price 1186.869995, investment 1.892125 %, total balance 11207.810483,
# day 182: buy 1 unit at price 1166.089966, total balance 10041.720517
# day 184, sell 1 unit at price 1184.650024, investment 1.718128 %, total balance 11226.370541,
# day 185: buy 1 unit at price 1180.489990, total balance 10045.880551
# day 187, sell 1 unit at price 1193.469971, investment 2.635836 %, total balance 11239.350522,
# day 188, sell 1 unit at price 1195.310059, investment 1.699957 %, total balance 12434.660581,
# day 189, sell 1 unit at price 1200.109985, investment 2.478035 %, total balance 13634.770566,
# day 191, sell 1 unit at price 1168.189941, investment 0.180087 %, total balance 14802.960507,
# day 194, sell 1 unit at price 1138.819946, investment -3.529894 %, total balance 15941.780453,
# day 195: buy 1 unit at price 1081.219971, total balance 14860.560482
# day 197: buy 1 unit at price 1110.079956, total balance 13750.480526
# day 198: buy 1 unit at price 1092.250000, total balance 12658.230526
# day 199: buy 1 unit at price 1121.280029, total balance 11536.950497
# day 201, sell 1 unit at price 1087.969971, investment 0.624295 %, total balance 12624.920468,
# day 202: buy 1 unit at price 1096.459961, total balance 11528.460507
# day 204, sell 1 unit at price 1103.689941, investment -0.575636 %, total balance 12632.150448,
# day 205: buy 1 unit at price 1050.709961, total balance 11581.440487
# day 207, sell 1 unit at price 1071.469971, investment -1.902498 %, total balance 12652.910458,
# day 208: buy 1 unit at price 1020.080017, total balance 11632.830441
# day 209: buy 1 unit at price 1036.209961, total balance 10596.620480
# day 211, sell 1 unit at price 1070.000000, investment -4.573347 %, total balance 11666.620480,
# day 214, sell 1 unit at price 1055.810059, investment -3.707377 %, total balance 12722.430539,
# day 215: buy 1 unit at price 1093.390015, total balance 11629.040524
# day 219: buy 1 unit at price 1036.050049, total balance 10592.990475
# day 220: buy 1 unit at price 1043.660034, total balance 9549.330441
# day 223: buy 1 unit at price 1020.000000, total balance 8529.330441
# day 224: buy 1 unit at price 1025.760010, total balance 7503.570431
# day 225: buy 1 unit at price 1037.609985, total balance 6465.960446
# day 227: buy 1 unit at price 1048.619995, total balance 5417.340451
# day 229, sell 1 unit at price 1086.229980, investment 3.380573 %, total balance 6503.570431,
# day 230, sell 1 unit at price 1088.300049, investment 6.687714 %, total balance 7591.870480,
# day 232, sell 1 unit at price 1106.430054, investment 6.776628 %, total balance 8698.300534,
# day 233, sell 1 unit at price 1050.819946, investment -3.893402 %, total balance 9749.120480,
# day 234, sell 1 unit at price 1068.729980, investment 3.154281 %, total balance 10817.850460,
# day 236: buy 1 unit at price 1039.550049, total balance 9778.300411
# day 237: buy 1 unit at price 1051.750000, total balance 8726.550411
# day 239, sell 1 unit at price 1061.900024, investment 1.747695 %, total balance 9788.450435,
# day 240: buy 1 unit at price 1042.099976, total balance 8746.350459
# day 241: buy 1 unit at price 1016.530029, total balance 7729.820430
# day 242: buy 1 unit at price 1028.709961, total balance 6701.110469
# day 243: buy 1 unit at price 1023.010010, total balance 5678.100459
# day 245: buy 1 unit at price 979.539978, total balance 4698.560481
# day 246: buy 1 unit at price 976.219971, total balance 3722.340510
# day 247: buy 1 unit at price 1039.459961, total balance 2682.880549
# day 248: buy 1 unit at price 1043.880005, total balance 1639.000544
# day 250: buy 1 unit at price 1035.609985, total balance 603.390559
# day 251, sell 1 unit at price 1045.849976, investment 2.534311 %, total balance 1649.240535,
# day 252: buy 1 unit at price 1016.059998, total balance 633.180537
# day 255, sell 1 unit at price 1076.280029, investment 4.925130 %, total balance 1709.460566,
# day 259: buy 1 unit at price 1044.689941, total balance 664.770625
# day 261, sell 1 unit at price 1080.969971, investment 4.178833 %, total balance 1745.740596,
# day 262, sell 1 unit at price 1089.900024, investment 3.936605 %, total balance 2835.640620,
# day 264: buy 1 unit at price 1070.520020, total balance 1765.120600
# day 265, sell 1 unit at price 1075.569946, investment 3.464951 %, total balance 2840.690546,
# day 268: buy 1 unit at price 1070.079956, total balance 1770.610590
# day 269: buy 1 unit at price 1060.619995, total balance 709.990595
# day 271, sell 1 unit at price 1116.369995, investment 6.144045 %, total balance 1826.360590,
# day 272: buy 1 unit at price 1110.750000, total balance 715.610590
# day 273, sell 1 unit at price 1132.800049, investment 8.703587 %, total balance 1848.410639,
# day 274, sell 1 unit at price 1145.989990, investment 12.735478 %, total balance 2994.400629,
# day 275, sell 1 unit at price 1115.229980, investment 8.410536 %, total balance 4109.630609,
# day 276: buy 1 unit at price 1098.709961, total balance 3010.920648
# day 278: buy 1 unit at price 1095.010010, total balance 1915.910638
# day 279, sell 1 unit at price 1121.369995, investment 9.614763 %, total balance 3037.280633,
# day 281, sell 1 unit at price 1121.670044, investment 14.509879 %, total balance 4158.950677,
# day 283: buy 1 unit at price 1118.560059, total balance 3040.390618
# day 284: buy 1 unit at price 1113.800049, total balance 1926.590569
# day 285: buy 1 unit at price 1096.969971, total balance 829.620598
# day 291, sell 1 unit at price 1140.989990, investment 16.878370 %, total balance 1970.610588,
# day 292: buy 1 unit at price 1147.800049, total balance 822.810539
# day 294, sell 1 unit at price 1157.859985, investment 11.390532 %, total balance 1980.670524,
# day 295: buy 1 unit at price 1143.300049, total balance 837.370475
# day 296, sell 1 unit at price 1142.319946, investment 9.430197 %, total balance 1979.690421,
# day 297, sell 1 unit at price 1175.760010, investment 13.533089 %, total balance 3155.450431,
# day 298, sell 1 unit at price 1193.199951, investment 17.434005 %, total balance 4348.650382,
# day 299, sell 1 unit at price 1193.319946, investment 14.227188 %, total balance 5541.970328,
# day 301, sell 1 unit at price 1184.459961, investment 10.643420 %, total balance 6726.430289,
# day 302, sell 1 unit at price 1184.260010, investment 10.670236 %, total balance 7910.690299,
# day 303, sell 1 unit at price 1198.849976, investment 13.032941 %, total balance 9109.540275,
# day 304, sell 1 unit at price 1223.969971, investment 10.193110 %, total balance 10333.510246,
# day 305, sell 1 unit at price 1231.540039, investment 12.089640 %, total balance 11565.050285,
# day 306, sell 1 unit at price 1205.500000, investment 10.090318 %, total balance 12770.550285,
# day 309: buy 1 unit at price 1173.020020, total balance 11597.530265
# day 310: buy 1 unit at price 1168.489990, total balance 10429.040275
# day 311: buy 1 unit at price 1173.310059, total balance 9255.730216
# day 312, sell 1 unit at price 1194.430054, investment 6.782827 %, total balance 10450.160270,
# day 313: buy 1 unit at price 1200.489990, total balance 9249.670280
# day 314: buy 1 unit at price 1205.920044, total balance 8043.750236
# day 315, sell 1 unit at price 1215.000000, investment 9.086007 %, total balance 9258.750236,
# day 316, sell 1 unit at price 1207.150024, investment 10.044035 %, total balance 10465.900260,
# day 317, sell 1 unit at price 1203.839966, investment 4.882376 %, total balance 11669.740226,
# day 318: buy 1 unit at price 1197.250000, total balance 10472.490226
# day 320: buy 1 unit at price 1204.619995, total balance 9267.870231
# day 322, sell 1 unit at price 1221.099976, investment 6.804856 %, total balance 10488.970207,
# day 323, sell 1 unit at price 1227.130005, investment 4.612878 %, total balance 11716.100212,
# day 324, sell 1 unit at price 1236.339966, investment 5.806637 %, total balance 12952.440178,
# day 325, sell 1 unit at price 1236.369995, investment 5.374533 %, total balance 14188.810173,
# day 326, sell 1 unit at price 1248.839966, investment 4.027520 %, total balance 15437.650139,
# day 327, sell 1 unit at price 1264.550049, investment 4.861848 %, total balance 16702.200188,
# day 328, sell 1 unit at price 1256.000000, investment 4.907079 %, total balance 17958.200188,
# day 329, sell 1 unit at price 1263.449951, investment 4.883694 %, total balance 19221.650139,

# %% [markdown]
# #Results:

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='b', label = 'Buying Signal to Agent', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'Selling Signal to Agent', markevery = states_sell)
plt.title('Evolution Strategy: \n \n Initial Investment: $12000 \n Revenue $%f \n Profit %f%% \n Total Balance: %f'%(total_gains, invest,portfolio[-1]))
plt.legend()
plt.ylabel('GOOGL Stock price ') 
plt.xlabel('5/19/2018 till 4/19/2019 ') 

plt.show()

# %%
portfolio = pd.DataFrame(portfolio)
investmentPortfolio = pd.DataFrame(investmentPortfolio)
rollingMeanInvest = investmentPortfolio.rolling(window=10).mean()
rollingMeanPort = portfolio.rolling(window=10).mean()

# %%
fig = plt.figure(figsize = (15,5))

plt.plot(portfolio, color='k',label = "Wallet", lw=2.)
plt.plot(rollingMeanPort,color='b',label = "Rolling Average", lw=2.)
plt.title('Wallet: \n \n Initial Investment: $12000 \n Revenue $%f \n Profit %f%% \n Total Balance: $%f \n'%(total_gains, portfolio.mean(),portfolio.mean()))
plt.legend()
plt.ylabel('Wallet $') 
plt.xlabel('\nAgent does not drain the investment ')
plt.show()

# %%
fig = plt.figure(figsize = (15,5))
rollingMean = investmentPortfolio.rolling(window=10).mean()
plt.plot(investmentPortfolio, color='r', lw=2.)
plt.plot(rollingMean)
#plt.plot(close, '^', markersize=10, color='b', label = 'Buying Signal to Agent', markevery = states_buy)
plt.title('Changes in Investment (Consequences of each Action) : \n  Average Pecentage Return: %%%.2f \n Maximum Return: %%%.2f \n Maximum Loss: %% %.2f\n'%(investmentPortfolio.mean(),investmentPortfolio.max(),investmentPortfolio.min()))

plt.legend()
plt.ylabel('Changes of Percent ') 
plt.xlabel('\nOverall a positive return, with few bad investment choices') 

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
investmentPortfolio.describe()
# Out:
#                 0
# count  112.000000
# mean     6.034873
# std      4.797104
# min     -4.573347
# 25%      2.610455
# 50%      5.946639
# 75%      9.721950
# max     17.434005

# %% [markdown]
# References:

# %% [markdown]
# https://arxiv.org/abs/1703.03864
#
# https://github.com/openai/evolution-strategies-starter
